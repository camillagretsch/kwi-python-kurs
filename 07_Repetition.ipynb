# %% [markdown]
# # Auffrischung Programmieren
#
# Jupyter ist wie ein interaktives Script, das aus Textzellen und ausführbaren Codezellen besteht.
#
# In diesem Notebook frischen Sie Ihre Programmierkenntnisse mit Python auf und erinnern sich an den Umgang mit Jupyter-Notebooks und der Erstellung von Notizen mit Markdown.
#
# ---
#
# ## Zellen
#
# Einerseits können Zellen **Text** enthalten, andererseits können Sie in **Codezellen** ausführbaren Code schreiben.
#
# Um neue Zellen zu erstellen klicken Sie auf das `+` im Menü oben und danach wählen Sie die Art der Zelle. Für diesen Kurs benötigen Sie `Markdown` für Textzellen und `Code` für Codezellen.
#
# Angewählte Zellen lassen sich mit den Pfeilbuttons (hellblau markiert) nach oben bzw. unten verschieben.
#
# ### Zellen ausführen
#
# Eine einzelne Zelle können Sie entweder mit dem Button `Run` im grün markierten Bereich ausführen oder mit der Tastenkombination [Shift]+[Enter].
#
# ### Kernel
#
# Der Kernel kümmert sich um die Ausführung des Pythoncodes im Notebook. In code-server muss immer der Kernel **venv (Python 3.12.3)** ausgewählt sein.
#
# #### Erste Hilfe: Was tun, wenn Ihr Programm hängenbleibt?
#
# Ist links der Zelle zwischen eckigen Klammern ein `[*]` zu sehen, so wird die Zelle gerade ausgeführt oder sie wartet darauf, ausgeführt zu werden. Wenn Sie die Ausführung stoppen möchten, können Sie dazu den Kernel unterbrechen (Kernelmenü oder Button ◼️).
#
# Manchmal ist es auch hilfreich, den Kernel zu stoppen und gleich wieder alle Zellen auszuführen, was mit Run All erreicht werden kann. Über den Button mit dem runden Pfeil können Sie den Kernel neu starten. Dabei werden alle Ausgaben gelöscht und die Zellen müssen erneut ausgeführt werden. Falls nichts mehr geht, coder schliessen und neu starten.
#
# Links, ausserhalb der Codezellen Zelle sehen Sie, in welchem Zustand sich diese befinden:
# * `In [*]` Zellen, die ausgeführt werden oder auf die Ausführung warten
# * `In [ ]` noch nicht ausgeführte Zellen
# * `In [Zahl]`, bereits ausgeführte Zellen

# %% [markdown]
# ## Codezellen
#
# Codezellen können Code in der angegebenen Sprache lesen und ausführen. Welche Programmiersprache verwendet wird, steht links unten im Fenster, hier ist es **Python**.
#
# In der folgenden Zelle wird eine Variable `a` definiert, die gleich den Wert 5 zugewiesen bekommt.
#
# **Aufgabe 1 – Codezelle ausführen**
#
# Führen Sie die folgende Zelle aus.

# %%
a = 5

# %% [markdown]
# Nachdem Sie die Zelle ausgeführt haben, ist die Variable definiert und Sie können nun in einer anderen Zelle darauf zugreifen.
#
# **Aufgabe 2 – Was bereits ausgeführt wurde, kann genutzt werden**
#
# Schauen Sie sich die folgende Zelle an. Überlegen Sie sich, welchen Output Sie erwarten und führen Sie die Zelle aus.

# %%
print(a)

# %% [markdown]
# ## Programmier-Warm-Up
#
# Bevor Sie neue Programmierkonzepte kennenlernen, werden Sie nun Ihr Können etwas auffrischen.
#
# ### Variablen
#
# Variablen können Sie sich als Behälter vorstellen, in dem beliebige Werte gespeichert werden können. Variablen sind nicht konstant, ihr Wert kann sich immer wieder ändern (ist *variabel*).
#
# #### Variablennamen
#
# Beachten Sie die folgenden Regeln, wenn Sie Variablennamen aussuchen:
#
# * Klein- und Grossschreibung
# * Sinnvolle Variablennamen tragen wesentlich zur Lesbarkeit und zum Verständnis des Codes bei
# * Keine von der Programmiersprache reservierte Ausdrücke als Variablennamen verwenden
# * Sie dürfen nicht mit Zahlen oder Sonderzeichen beginnen
#
# #### Variablenwerte verändern
#
# Häufig müssen Werte von Variablen schnell angepasst werden, wobei der neue Wert abhängig vom aktuellen Wert ist. Dazu gibt es die folgende Kurzform:
#
# ```Python
# zahl = 10 # Variablendefinition, danach existiert die Variable und kann verändert werden.
# zahl += 1 # Kurzform für zahl = zahl + 1
# zahl -= 2 # Kurzform für zahl = zahl - 2
# zahl *= 3 # Kurzform für zahl = zahl * 3
# zahl /= 4 # Kurzform für zahl = zahl / 4
# ```
#
# In Python passt sich der Datentyp einer Variablen jeweils dem Wert an, der gerade in der Variablen gespeichert ist.

# %% [markdown]
# ### Datentypen
#
# Sie haben die folgenden Datentypen kennengelernt:
#
# | Datentyp    | Bedeutung          | Beispiel | Wertebereich                                   |
# | :---------- | :----------------- | :------- | :--------------------------------------------- |
# | **Boolean** | *Wahrheitswert*    | True     | {True, False}                                  |
# | **Integer** | *Ganzzahl*         | 5        | $\mathbb{Z}$                                   |
# | **Float**   | *Fliesskommazahl*  | 1.25     | $\mathbb{R}$                                   |
# | **String**  | *Zeichenkette*     | "Hallo"  | Zeichenketten, gekennzeichnet mit "" oder '' |
#
# Den Datentypen abfragen können Sie mit der Funktion `type()`:
#
# ```Python
# x = 5
# type(x)
# ```
# liefert den Wert `int` oder mit der print-Funktion, etwas «aufbereitet»: `<class 'int'>`.
#
# **Aufgabe 3 – Variablen und Datentypen**
#
# Definieren Sie die vier Variablen `stimmts`, `jahreszahl`, `pi` und `begruessung` und weisen Sie ihnen je einen der folgenden Werte zu:
# * 3.14159265359
# * True
# * "Guten Morgen!"
# * 2023
#
# Schreiben Sie dahinter je in einem Kommentar, um welchen Datentyp es sich handelt (Sie erinnern sich an die Raute `#`...).
#
# Überprüfen Sie anschliessend mit der Funktion `type()`, ob die Variablen die erwarteten Typen aufweisen.

# %%
# Ihr Code...
stimmts = ...

# Überpfüung
print(type(stimmts))
# Out:
# <class 'bool'>

# %% [markdown]
# ### EVA-Prinzip
#
# Wenn Daten verarbeitet werden, geschieht dies nach dem «EVA-Prinzip»: Das Programm nimmt Daten entgegen (**E**ingabe, Input), verarbeitet sie (**V**erarbeitung) und gibt am Ende das Resultat, also die verarbeiteten Daten, wieder aus (**A**usgabe, Output).
#
# #### Eingabe
#
# Mit der Funktion `input()` können Sie Ihre Benutzerinnen und Benutzer um eine Eingabe bitten und diese einlesen. Beachten Sie dabei, dass der eingelesene Input immer als String (Zeichenkette) daherkommt.
#
# *Falls Sie einen anderen Datentypen benötigen, können Sie die Eingabe mit den Funktionen `int()` bzw. `float()` in den gewünschten Datentypen umwandeln.*
#
# Wenn Sie einen Float in einen Integer zwängen, verlieren Sie die Kommastellen:
#
# ```Python
#     zahl = int(1.9)
#     print(zahl)
# ```
# --> Ausgabe: 1
#
# Sehen Sie sich die Beispiele an:

# %%
# Hier erwarten Sie einen String
name = input("Wie heisst Du? ")
print("Hallo", name + "!")

# %%
# Hier erwarten Sie eine Zahl. 
zahl = input("Gib eine Zahl ein. ")
# Ausgabe zum Sicherstellen, dass Sie sehen, was eingelesen wurde...
print("Deine Zahl:", zahl, "ist vom Datentyp", type(zahl))
# Diese Eingabe werden Sie umwandeln müssen, denn mit einem String können Sie nicht rechnen...
print("zahl mal 2:", zahl * 2)

# Wenn Sie Strings multiplizieren, werden diese aneinandergehängt. 
# Das ist hier nicht das, was Sie wollen.
# Deshalb müssen Sie die Eingabe umwandeln:
ganzzahl = int(input("Gib eine Ganzzahl ein. "))
# Ausgabe zum Sicherstellen, dass Sie sehen, was eingelesen wurde...
print("Deine Zahl:", ganzzahl, "ist vom Datentyp", type(ganzzahl))
# Nun können Sie mit Ihrer Eingabe rechnen
print("zahl mal 2 (mit Umwandlung in einen Integer):", ganzzahl * 2)

# %% [markdown]
# #### Ausgabe
#
# Sie erinnern sich, dass Sie mit der Funktion `print()` eine Ausgabe machen können. `print` kann beliebig viele Parameter von verschiedenen Datentypen entgegennehmen. Beim Darstellen wird jeweils ein Leerschlag zwischen zwei Ausgaben gemacht.
#
# Am Ende von `print` kommt ein Zeilenumbruch.
#
# Hier sehen Sie ein paar Beispiele, ergänzen Sie welche, wenn Sie etwas ausprobieren möchten.

# %%
# Ein einzelner Parameter: 
print("Hallo!")

begruessung = "Guten Morgen!"
print(begruessung)

# print gibt alle möglichen Datentypen aus
print(1, 2, "drei", True, 1.25)

# Nur den Zeilenumbruch ausgeben (ergibt eine Leerzeile...)
print()

print ("Hallo und", begruessung) # beachten Sie das Leerzeichen nach und...

# Zahlen von 0 bis und ohne 5 ausgeben, aber getrennt durch einen Leerschlag, (statt einen Zeilenumbruch)
for i in range(5):
    print(i, end=" ")
    
# Warum end=" "? Am Ende jeder Ausgabe steht statt eines 
# Zeilenumbruchs ein Leerschlag. Ohne Leerschlag wäre dies:
for i in range(5):
    print(i, end="")

# %% [markdown]
# **Aufgabe 4 – Ein- und Ausgabe**
#
# Fragen Sie noch nach einer Fliesskommazahl (Float) und geben Sie den erhaltenen Wert aus.

# %%
# Ihr Code...

# %% [markdown]
# ###  Operatoren
#
# Sie haben bereits verschiedene Operatoren kennengelernt:
#
# #### Zuweisungsoperator =
#
# Wenn Sie einer Variable einen Wert zuweisen wollen, benötigen Sie den Zuweisungsoperator `=`:
#
# ```Python
# meine_variable = 5
# ```
#
# #### Arithmetische Operatoren
#
# Arithmetische Operatoren werden auf Zahlenwerte angewendet, das Resultat ist wiederum eine Zahl.
#
# | Operator | Operation              | Beispiel    | Resultat                                                 |
# | :------: | :--------------------- | :---------- | :------------------------------------------------------- |
# | **+**    | *Addition*             | 1 + 2 = 3   | Summe                                                    |
# | **-**    | *Subtraktion*          | 4 - 3 = 1   | Differenz                                                |
# | _*_      | *Multiplikation*       | 2 \* 3 = 6  | Produkt                                                  |
# | **/**    | *Division*             | 6 / 3 = 2   | Quotient                                                 |
# | **//**   | *ganzzahlige Division* | 7 // 3 = 2  | Quotient (nur ganzzahliger Teil, keine Nachkommastellen) |
# | **%**    | *Modulo*               | 7 % 3 = 1   | Rest einer Division                                      |
# | _**_     | *Potenz*               | 2 ** 3 = 8  | Potenzwert                                               |
#
# #### Vergleichsoperatoren (Relationale Operatoren)
#
# Vergleichsoperatoren dienen dem Vergleich von Werten, das Ergebnis ist ein Wahrheitswert (Boolean).
#
# | Operator | Bedeutung          | Beispiel | Löst nach True auf, wenn... |
# | :------: | :----------------- | :------- | :-------------------------- |
# | **<**    | *kleiner als*      | a < b    | a kleiner ist als b.        |
# | **<=**   | *kleiner gleich*   | a <= b   | a kleiner gleich b ist.     |
# | **>**    | *grösser als*      | a > b    | a grösser ist als b.        |
# | **>=**   | *grösser gleich*   | a >= b   | a grösser gleich b ist.     |
# | **==**   | *gleich*           | a == b   | a und b gleich sind.        |
# | **!=**   | *ungleich*         | a != b   | a und b nicht gleich sind.  |
#
# **Aufgabe 5 – Vergleichsoperatoren (Relationale Operatoren)**
#
# Erstellen Sie zwei Variablen `a` und `b` und weisen Sie ihnen je einen Zahlenwert zu. Vergleichen Sie die beiden Variablen und beobachten Sie, ob der Vergleich jeweils das Resultat `True` oder `False` liefert.

# %%
# Ihr Code...

# %% [markdown]
# #### Logische Operatoren (Boolesche Operatoren)
#
# Boolesche Operatoren (oder logische Operatoren) dienen der logischen Verknüpfung von Wahrheitswerten (Booleans).
#
# | Operator  | Beschreibung                | Ausdruck  | Gibt wahr (`True`) zurück, wenn...   |
# |:---------:|:----------------------------|:----------|:-------------------------------------|
# | **`not`** | NOT; «nicht»                | `not a`   | `a` `False` ist.                     |
# | **`and`** | AND; «and«                  | `a and b` | `a` und `b` `True` sind.             |
# | **`or`**  | OR; «oder» (einschliessend) | `a or b`  | `a` oder `b` oder beide `True` sind. |
#
# **Aufgabe 6 – Logische Operatoren**
# Beobachten Sie, was herauskommt, wenn Sie die beiden Variablen something_false und something_true mit den logischen Operatoren and und or verknüpfen oder not darauf anwenden.

# %%
something_true = True
something_false = False

# Beispiel And:
print(something_true and something_true)
print(something_true and something_false)
print(something_false and something_false)

# Ihr Code...

# %% [markdown]
# ### Kontrollstrukturen
#
# Kontrollstrukturen steuern den Ablauf eines Programms. Die folgenden Verzweigungen und Wiederholungen (Schleifen) sollten Sie bereits kennen.
#
# #### Verzweigungen
#
# Mit Verzweigungen werden Entscheidungen abgebildet.
#
# Sie können Bedingungen aufzustellen, unter denen gewisse Codeblöcke ausgeführt werden. Die Bedingung ist eine logische Aussage. Sie liefert `True` oder `False` zurück. Bedingungen enthalten meist Vergleichsoperatoren (==, !=, <, <=, >, >=) und/oder logische Operatoren (not, and, or).
#
# Verzweigungen können einseitig, zweiseitig oder mehrstufig sein:
#
# * **einseitig** (nur `if`):
#   ```Python
#     if Bedingung:
#         # Körper 1 (wird ausgeführt, wenn die Bedingung auf True auflöst)
#   ```
#   Falls die `Bedingung` richtig (`True`) ist, wird der Codeblock `Körper 1` ausgeführt.
#
# * **zweiseitig** (`if` ... `else`):
#   ```Python
#     if Bedingung:
#         # Körper 1 (wird ausgeführt, wenn die Bedingung auf True auflöst)
#     else:
#         # Körper 2 (wird ausgeführt, wenn die Bedingung nicht auf True auflöst)
#   ```
#   Falls die `Bedingung` richtig (`True`) ist, wird der Codeblock `Körper 1` ausgeführt, ansonsten wird der Codeblock `Körper 2` ausgeführt.
#
# * oder **mehrstufig** (`if` ... `elif` ... `else`)
#   ```Python
#     if Bedingung1:
#         # Körper 1 (wird ausgeführt, wenn die Bedingung1 auf True auflöst)
#     elif Bedingung2:
#         # Körper 2 (wird ausgeführt, wenn die Bedingung2 auf True auflöst)
#     else:
#         # Körper 3 (wird ausgeführt, wenn weder die Bedingung1 noch die Bedingung2 auf True auflöst)
#   ```
#   Falls die `Bedingung1` richtig ist (`True`) wird der Codeblock `Körper 1` ausgeführt. Falls die `Bedingung1` falsch (`False`) ist, wird die `Bedingung2` geprüft. Falls die `Bedingung2` richtig (`True`) ist, wird der Codeblock `Körper 2` ausgeführt. Ansonsten wird der Codeblock `Körper 3` ausgeführt.
#
# Erlaubt sind auch mehrere **elif**-Blöcke sowie verschachtelte Bedingungen.
#
# ```Python
# if Bedingung:
#     if Bedingung1:
#         # Körper 1 (wird ausgeführt, wenn die Bedingung1 auf True auflöst)
#     elif Bedingung2:
#         # Körper 2 (wird ausgeführt, wenn die Bedingung2 auf True auflöst)
#     else:
#         # Körper 3 (wird ausgeführt, wenn weder die Bedingung1 noch die Bedingung2 auf True auflöst)
# else:
#     # Körper 4 (wird ausgeführt, wenn die Bedingung nicht auf True auflöst)
# ```

# %% [markdown]
# **Aufgabe 7 – Verzweigungen**
#
# Im Kontext der logischen Operatoren haben Sie auch die Funktion Modulo kennengelernt. Sie gibt den Rest einer Division zurück.
#
# Schreiben Sie ein Programm, das den Benutzer/die Benutzerin nach einer Zahl fragt und ausgibt, ob die Zahl durch 4 teilbar ist oder nicht.

# %%
# Ihr Code...

# %% [markdown]
# #### For-Schleifen
#
# For-Schleifen sind *zählergesteuerte* Schleifen. Sie verwenden eine Schleifenvariable, die solange erhöht wird bis sie den maximal Wert erreicht, danach wird die Schleife wieder verlassen.
#
# * For-Schleifen sind folgendermassen aufgebaut:
#   ```Python
#   for i in range(anzahl): # Schleifenkopf
#       # Schleifenkörper
#   ```
#
#     * i: Schleifenvariable, nimmt ganzzahlige Werte von 0 *bis und ohne* anzahl an
#     * anzahl gibt die Anzahl Wiederholungen an
#     * z. B. `for i in range (5)`, ist der untere Rand des Bereichs 0, der Bereich geht also automatisch **von 0** bis 4.
#
# **Aufgabe 8 – Schleifen**
#
# Verwenden Sie die for-Schleife und erstellen Sie die folgende Ausgabe:
#
# ```
# Durchgang 1
# Durchgang 2
# Durchgang 3
# Durchgang 4
# Durchgang 5
# Durchgang 6
# Durchgang 7
# Durchgang 8
# Durchgang 9
#
# ```

# %%
# Ihr Code...
