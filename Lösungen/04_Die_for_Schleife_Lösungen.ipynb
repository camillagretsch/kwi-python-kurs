# %% [markdown]
# # Automatische Wiederholung mit der for-Schleife
#
# Bisher hat der Computer unsere Programme immer von oben nach unten Zeile für Zeile ausgeführt. Bei den Aufgaben in den vorherigen Notebooks mussten wir uns aber sehr oft wiederholen, z. B. bei einem Quadrat, wo wir folgenden Code benötigten:
#
# ```Pyton
# # Vergiss nicht, dasss auch in diesem Notebook immer zuerst der Screen gezeichnet werden muss!
# (t, tScreen) = prepareTurtleGraphics()
#
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# t.forward(100)
# t.left(90)
# ```
# Beim Programmieren möchten wir uns aber das Leben einfach machen und die selbe Anweisung, wenn möglich nur einmal schreiben. Stellen Sie sich vor Sie müssen ein 360-Eck zeichnen. Die Anweisung wäre dann 360 mal:
# ```
# Geh x Schritte nach vorne
# Dreh dich um 1 Grad
# ```
#
# Um uns diese Mühe zu sparen, können wir Schleifen verwenden. In Python gibt es zwei Arten von Schleifen:
#
# * Die **for-Schleife** lernen Sie heute kennen und
# * die **while-Schleife**, welche zu einem späteren Zeitpunkt dran kommt.
#
#
# **Hausaufgabe**: Machen Sie dieses Notebook fertig und stellen Sie sicher, das Sie die folgenden Ziele erreichen:
#
# ---
# **Ziele**
#
# * Sie verwenden eine for-Schleife, um Befehle wiederholt ausführen zu lassen und somit ein Python-Programm kompakter zu gestalten.
# * Sie wissen wie eine for-Schleife aufgebaut ist und können Schleifenkopf, Schleifenvariable und Schleifenkörper bestimmen.
# * Sie notieren den Programmablauf für ein gegebenes Python-Programm, ohne dabei das Programm am Computer ausführen zu lassen.
# * Sie setzen das `random`-Modul (“Zufallsmodul”) in einem Python-Programm ein.
# ---
#
#
# Eine for-Schleife besteht jeweils aus dem **Schleifenkopf**, welcher die **Schleifenvariable** `i` enthält und dem **Schleifenkörper**.
# Der **Schleifenkopf** bestimmt dabei die Anzahl Durchläufe und die **Schleifenvariable** und sieht so aus:
#
# ```Python
# for i in range(anzahl_wiederholungen):
# ```
# Der **Schleifenkörper** enthält den Code, der mehrfach ausgeführt werden soll. Er ist durch **Einrücken** markiert.
#
# Für das obige Beispiel sieht die gesamte for-Schleife so aus:
#
# ```Python
# for i in range(360): # Schleifenkopf (Achten Sie auch auf den Doppelpunkt)
#     t.fd(3)          # Schleifenkörper (eingerückter Block)
#     t.lt(1)
# ```
#
# ***
#
# **Aufgabe 1.1**: Führen Sie zuerst wieder den unteren Befehl aus, um bei den späteren Aufgaben eine Turtle und eine Zeichenfläche zu erhalten. Schreiben Sie dann Ihre erste for-Schleife, welche ein Quadrat zeichnet.
#
# **Aufgabe 1.2**: Kürzen Sie den Code mit Hilfe einer for-Schleife ab! Was wird hier gezeichnet?
# (Mit je 3 ' vor und nach mehrere Zeilen kann ein Bereich auskommentiert werden.)
#
# **Aufgabe 1.3**: Schreiben Sie ein Programm, welches ein 6-Eck zeichnet wie im Bild unten in a).
# * Wie hängen Winkel und Anzahl Wiederholungen zusammen? Können Sie den Code auch so abändern, dass ein 6-Eck entsteht?
#   Tipp: Lassen Sie den Computer für Sie rechnen. Um wieviel muss sich die Turtle insgesammt um sich selbst drehen, damit ein Stern entsteht?
#
#
# Zeichnen Sie auch noch Figuren c) und d) (Quelle: www.tigerjython4kids.ch)
#
# <img src="./bilder/03_for_loop_Aufgabe1_4.png" style="height:100px"/>

# %%
# Führen Sie auch in diesem Notebook die Zelle aus. 
# Sie definiert den Befehl, den Sie brauchen, um einen Zeichenbereich und eine Turtle zu erstellen.

import ipyturtle3 as turtle

def prepareTurtleGraphics(width=500, height=250):
    myCanvas = turtle.Canvas(width=width, height=height)
    display(myCanvas)
    turtleScreen = turtle.TurtleScreen(myCanvas)
    turtleScreen.clear()
    t = turtle.Turtle(turtleScreen)
    t.shape("turtle")
    turtleScreen.bgcolor("floralwhite")
    return (t, turtleScreen)

# %%
# Lösung Aufgabe 1.1
(t, tScreen) = prepareTurtleGraphics()


for i in range(4):
    t.forward(100)
    t.left(90)

# %%
# Lösung: 1.2
(t, tScreen) = prepareTurtleGraphics()
for i in range(8):
    t.fd(100)
    t.bk(100)
    t.lt(45)

# %%
# Lösung 1.3

# a)
(t1, tScreen1) = prepareTurtleGraphics()

for i in range(6):
    t1.fd(80)
    t1.lt(360/6)

# b)
(t2, tScreen2) = prepareTurtleGraphics()

for i in range(5):
    t2.fd(80)
    t2.lt(360/5)

# c)   
(t3, tScreen3) = prepareTurtleGraphics()

for i in range(5):
    t3.fd(150)
    t3.lt(360*2/5)
     
# d)
(t4, tScreen4) = prepareTurtleGraphics()

for i in range(9):
    t4.fd(150)
    t4.lt(360*4/9)
# Out:
# Canvas(height=250, width=500)
# Canvas(height=250, width=500)
# Canvas(height=250, width=500)
# Canvas(height=250, width=500)

# %% [markdown]
# ## Ein genauerer Blick in den Schleifenkopf
#
# **Aufgabe 2**. Wofür brauchen wir eine Schleifenvariable überhaupt?
# Versuchen Sie mal herauszufinden, was mit der Schleifenvariable passiert während dem ausführen einer for-Schleife. Benutzen sie dazu z.B. einen `print()`-Befehl, der jeweils die Schleifenvariable ausgibt.

# %%
# Testen Sie hier, was mit der Schleifenvariable passiert.

for i in range(5):
    print(i)

# %% [markdown]
# Sie sollten bemerkt haben, dass die Schleifenvariable mit dem Wert 0 startet und dann hochzählt bis 1 unter den Wert, welcher in der range-Funktion steht. Die Schleifenvariable existiert nur solange die Schleife ausgeführt wird. Nach dem letzten Durchgang wird nochmals der Schleifenkopf ausgeführt und die Schleifenvariable wird wieder gelöscht.
# **Wichtig** ist, dass der Computer beim Ausführen des Codes vor jedem Schleifendurchgang auch den Schleifenkopf ausführt und dabei die Schleifenvariable erhöht. Bei folgendem Code würde dies folgendes bedeuten:
#
# ```Python
# 1 for i in range(4):
# 2    t.fd(100)
# 3    t.lt(90)
# 4 t.fd(100)
# ```
#
#
# | Zeile   |      Wert der Schleifenvariable      |  Kommentar |
# |:----------|:---------------|:-------|
# |1 | i = 0 | Eine Variable **i mit dem Wert 0** wird kreiert, nachdem die Zeile ausgeführt wurde. |
# |2 | i = 0 | i speichert immer noch den Wert 0. |
# |3 | i = 0 | i speichert immer noch den Wert 0. |
# |1 | i = 1 | **i wird auf 1** gesetzt, nachdem die Zeile ausgeführt wurde. |
# |2 | i = 1 | i speichert immer noch den Wert 1. |
# |3 | i = 1 | i speichert immer noch den Wert 1. |
# |1 | i = 2 | **i wird auf 2** gesetzt, nachdem die Zeile ausgeführt wurde. |
# |2 | i = 2 | i speichert immer noch den Wert 2. |
# |3 | i = 2 | i speichert immer noch den Wert 2. |
# |1 | i = 3 | **i wird auf 3** gesetzt, nachdem die Zeile ausgeführt wurde. |
# |2 | i = 3 | i speichert immer noch den Wert 3. |
# |3 | i = 3 | i speichert immer noch den Wert 3.
# |**1**|**-**| **nach dem Ausführen des Schleifenkopfs wird die Variable i wieder vergessen**|
# |4 | - | die Turtle bewegt sich noch 100 vorwärts und das Programm wird beendet.|

# %% [markdown]
# Man kann die for-Schleife sehr gut dazu brauchen, um Figuren zu zeichnen, welche das selbe Muster in unterschiedlichen Grössen immer wieder erstellt. So kann z.B. eine Spirale gezeichent werden, welche wie folgt aussieht:
#
# <img src="./bilder/03_for-Schleife_Aufgabe_3.png" style="height:200px"/>
#
#
# **Aufgabe 3**: Finden Sie heraus was, mit der Variable `seite` in jedem Durchlauf der Schleife passieren muss, damit Sie auch eine Spirale zeichnen können.

# %%
# Lösung Aufgabe 3

(t, tScreen) = prepareTurtleGraphics()

seite = 5

for i in range(40):
    t.fd(seite)
    t.lt(90)
    seite += 5 # seite += 5 ist eine Abkürzung für: seite = seite + 5

# %% [markdown]
# Lösen Sie die folgenden Aufgaben, um den Lernstoff zu festigen:
#
# **Aufgabe 4.1**: Fragen Sie den Benutzer nach einem Input für die Anzahl Ecken und zeichnen Sie anschliessend ein Vieleck mit dieser Anzahl Ecken.
#
# **Aufgabe 4.2**: Schreiben Sie ein Programm, welches die Quadratzahlen der Zahlen 0-9 ausgibt.
#
# Für die nächste Aufgabe benötigen Sie einen neuen Befehl, welcher im Modul **random** ist. Dazu müssen wir es zuerst **importieren**. Wir werden die Funktion random.randint(untere_schranke, obere_schranke) brauchen, welche uns eine zufällige Zahl zwischen den beiden Schranken gibt. Also der Befehl random.randint(3, 12) gibt eine Zufallszahl zwischen 3 und 12 aus.
#
# **Aufgabe 4.3**: Schreiben Sie ein Programm, welches uns 10 Zufallszahlen ausgibt, in den Bereichen [0,1], [0,2], [0,3], ... , [0,10].
#
# **Aufgabe 4.4**: Zeichnen Sie folgendes Muster: Zinnen, welche die Farbe zwischen blau und rot wechseln
#
# <img src="./bilder/03_for_Schleife_Aufgabe_4.4.png" style="height:50px"/>

# %%
# Lösung Aufgabe 4.1

ecken = int(input("Gib die Anzahl Ecken ein: "))

(t, tScreen) = prepareTurtleGraphics()

for i in range(ecken):
    t.forward(50)
    t.left(360/ecken)

# %%
# Lösung Aufgabe 4.2 

for i in range(10):
    print(i**2)

# %%
# Lösung Aufgabe 4.3 
import random # Mit dieser Zeile sagen wir dem Computer, dass wir Befehle aus dem random Modul brauchen. 

for i in range(10):
    print(i+1, ":", random.randint(0, i+1))

# %%
# Lösung Aufgabe 4.4
(t, tScreen) = prepareTurtleGraphics()
t.pu()
t.goto(-200, 0)
t.pd()
for i in range(10):
    t.color("red")
    t.fd(20)
    t.lt(90)
    t.fd(20)
    t.rt(90)
    t.color("blue")
    t.fd(20)
    t.rt(90)
    t.fd(20)
    t.lt(90)

# %% [markdown]
# ## Abschluss
#
# Sie sollten nun in der Lage sein, Schleifen zu verwenden, um Befehle wiederholt auszuführen. Zusätzlich kennen Sie den Schleifenkopf und vorallem die Schleifenvariable, welche später noch von grossem Nutzen sein wird. Daneben haben Sie noch ein weiteres Modul von Python kennengelernt, welches Zufallszahlen generieren kann.
#
#
# ### ✅ Kontrollfragen und Prüfungsvorbereitung
#
# 1. Was ist ein Schleifenkopf, -körper und -variable?
#    Schreiben Sie eine Schleife und markieren Sie die entsprechenden Teile.
#
# 2. Wie werden bei folgendem Programm die Zeilen abgearbeitet? Schreiben Sie die Reihenfolge der Zeilen hin. zB 1, 4, 5, 6, 5, 6, 7, 3, 9.
#
# ```Python
# 1 (t, tScreen) = prepareTurtleGraphics()
# 2
# 3 ecken = 3
# 4 for i in range(ecken):
# 5    t.forward(50)
# 6    t.left(360/ecken)
# 7
# 8 t.forward(30)
# ```
# 3. a) Wieviele print()-Befehle werden in folgendem Programm ausgeführt? b) Was wird ausgegeben?
#
# ```Python
# a = 2
# b = 5
#
# for i in range(3):
#     print(i, a, b)
#     a = i + 2
#     b += a
#
# print(a, b)
# ```

# %% [markdown]
# ### 💡 Challenge (freiwillig)
#
# Wie könnten Sie ein Fünfeck mit gestrichelten Linien zeichnen?
#
# <img src="./bilder/03_challenge.png" style="height:100px"/>

# %%
# Lösung Challenge
(t, tScreen) = prepareTurtleGraphics()

for j in range(5):
    for i in range(5):
        t.fd(5)
        t.penup()
        t.fd(5)
        t.pendown()
    t.left(360/5)
t.hideturtle()
