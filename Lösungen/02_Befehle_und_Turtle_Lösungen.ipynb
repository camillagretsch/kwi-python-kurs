# %% [markdown]
# # Programme bestehen aus Befehlen
#
# Anders als wenn Sie mit anderen Menschen kommunizieren, müssen Sie mit dem Computer so «sprechen», dass er Sie versteht, denn Sie haben nicht die Möglichkeit, durch Gesten eine Aussage zu verdeutlichen. Sie haben bereits gelernt, dass dazu eine Programmiersprache verwendet wird – in unserem Falle Python – und Sie wissen, dass Programmcode in Jupyter Notebooks wie diesem in Codezellen geschrieben wird und diese Zellen ausgeführt werden können.
#
# In diesem Notebook werden Sie lernen, wie einfache Python-Befehle aufgebaut sind, wie daraus ein Programm entsteht und wie der Computer dieses Programm abarbeitet. Im letzten Teil haben Sie den Datentypen String für Text kennengelernt. Nun werden Sie erfahren, wie Zahlen dargestellt werden und wie Sie mit ihnen rechnen können.
#
# Ausserdem lernen Sie heute die «Turtle» kennen. Sie können sie mit wenigen Befehlen so programmieren, dass sie zeichnet.
#
# **Hausaufgabe**: Machen Sie dieses Notebook fertig und stellen Sie sicher, das Sie die folgenden Ziele erreichen:
#
# ---
# **Ziele**
#
# * Sie wissen, dass *Programme* aus *Befehlen* bestehen, die *von oben nach unten* abgearbeitet werden.
# * Sie erkennen, dass auskommentierte Befehle nicht ausgeführt werden und können *Kommentare* nutzen, um überflüssige Befehle nicht auszuführen.
# * Sie erklären, wie ein *Befehl* aufgebaut ist.
# * Sie können die *Turtle* so programmieren, dass sie mit den Befehlen `forward()`, `back()`, `left()`, `right()`, `penup()` und `pendown()`, einfache Figuren zeichnet. Um die Zeichnungen aufzupeppen, können Sie die Stiftfarbe und Stiftdicke verändern.
# * Sie kennen die *Datentypen Integer und Float* für Ganz- und Fliesskommazahlen und die *arithmetischen Operatoren* `+`, `-`, `*`, `/`, `//`, `%`, `**`, die Sie auf Integer und Floats anwenden können.
# * Sie können den Datentyp eines Werts mit dem Befehl `type()` erfragen.
# ---
#
# Wenn Sie ausserhalb des Unterrichts Fragen haben, schreiben Sie diese bitte auf Teams – wenn möglich im Kursteam, damit es für alle sichtbar ist und Sie einander gegenseitig helfen können. Falls Sie Ihre Frage aber lieber persönlich stellen, können Sie auch den Teamschat nutzen.

# %% [markdown]
# ## 1. Ausführung eines Programms, einfache Befehle und Kommentare
#
# Wie ein Rezept aus der Beschreibung der einzelnen Arbeitsschritte besteht, ist Code aus Befehlen aufgebaut.
#
# Letzte Woche haben Sie den Befehl `print()` kennengelernt und damit Ihren Namen und Ihre Klasse ausgegeben:
#
# ```Pyton
# print("Andrea Huber")
# print("3k")
# ```
#
# Wenn Sie es ausführten, lautete die Ausgabe:
#
# ```
# Andrea Huber
# 3k
# ```
#
# Wenn Programmcode ausgeführt wird, werden die Befehle von oben nach unten abgearbeitet.
#
# Das sehen Sie daran, dass die Resultate dieser Befehle in der gleichen Reihenfolge ausgegeben werden, wie die `print()`-Befehle.
#
# Merken Sie sich folgendes:
#
# **Code wird immer von oben nach unten ausgeführt**, also zuerst die erste Zeile der Codezelle, dann die zweite Zeile usw.
#
# ### 1.1. Befehle
#
# Befehle sind eigentlich Aufrufe von Funktionen. Einfache Befehle werden immer gleich geschrieben:
#
# ```Python
# funktionsname(argumente, mit, Kommas, getrennt)
# ```
#
# Zwischen den Klammern können dem Befehl keines, eines oder mehrere Argumente übergeben werden. Der `print()`-Befehl kann beliebig viele Argumente entgegennehmen:
#
# `print()` gibt nicht mehr aus, als einen Zeilenumbruch,
# `print("hallo")` gibt `Hallo` aus, gefolgt von einem Zeilenumbruch,
# `print("heute schreibe", "ich lustige", "Programme", "heute schreibe ich lustige Programme", "!")` gibt `heute schreibe ich lustige Programme !` aus.
#
# ### 1.2. \# *Kommentare*
#
# Alles, was hinter einer Raute (`#`) steht, ist ein Kommentar und wird nicht ausgeführt:
#
# Wenn Sie wollen, dass eine Zeile oder ein Befehl nicht ausgeführt werden soll, können Sie diese mit `#` auskommentieren.
#
# ```Python
# print("Rate mal, welche Zahl ich mir merke!")
# # print("Ich merke mir die Zahl 7.")
# print("Los, sag schon...")
# ```
# Führen Sie die nächste Codezelle aus und Sie werden sehen, dass die zweite Zeile nicht ausgeführt wird:

# %%
print("Rate mal, welche Zahl ich mir merke!")
# print("Ich merke mir die Zahl 7.")
print("Los, sag schon...")
# Out:
# Rate mal, welche Zahl ich mir merke!
# Los, sag schon...

# %% [markdown]
# #### 1.2.1 Kommentare für Ihre Notizen
#
# Mit Kommentaren können Sie sich während dem Programmieren Notizen machen:
#
# ```Python
# print(4*5) # print wird das Resultat der Berechnung ausgeben, also 20.
# ```
#
# In diesem Beispiel gibt der Aufruf von `print(4*5)` tatsächlich 20 aus. Der Kommentar wird nicht ausgeführt.
#
# Code Editoren stellen Kommentare anders dar (hier türkis und kursiv). Diese **farbliche Hervorhebung** nennt man auch «**Syntax Highlighting**». Sie hilft uns, den Code einfacher zu lesen.
#
# ---
# **Aufgabe 1** – Code Ausführen und Zeilen auskommentieren
#
# Die folgende Codezeile enthält ein paar `print()`-Befehle. Die erste Strophe des Mani Matter-Lieds ist durcheinander geraten. *Eine* Zeile ist verrutscht und es haben sich Zeilen aus einer anderen Strophe eingeschlichen. Bringen Sie die Zeilen in die richtige Reihenfolge und kommentieren Sie die überflüssigen Zeilen aus, damit nur die erste Strophe wie folgt in der Ausgabe steht:
#
# ```
# I han es Zündhölzli azündt von Mani Matter
# ------------------------------------------
# I han es Zündhölzli azündt
# Und das het e Flamme gäh
# Und i ha für d'Zigarette
# Welle Füür vom Hölzli näh
# Aber s'Hölzli isch dervo-
# Gspickt und uf e Deppich cho
# Und es hätt no fasch es Loch in Deppich gäh dervo
# Ja me weis was cha passiere```

# %%
# Aufgabe 1 – Lösung:
print("I han es Zündhölzli azündt von Mani Matter")
print("------------------------------------------")
print("I han es Zündhölzli azündt")
print("Und das het e Flamme gäh")
#print("Und vom Deppich hätt o Grus")
#print("Chönne s'Füür is ganze Hus")
print("Und i ha für d'Zigarette") # <--- verrutschte Zeile gehört hierher
print("Welle Füür vom Hölzli näh")
print("Aber s'Hölzli isch dervo-")
print("Gspickt und uf e Deppich cho")
#print("Und s'hätti d'Füürwehr müesse cho")
#print("Hätti ghornet i de Strasse")
#print("Und dr Schluuch vom Wage gno")
print("Und es hätt no fasch es Loch in Deppich gäh dervo")
# Out:
# I han es Zündhölzli azündt von Mani Matter
# ------------------------------------------
# I han es Zündhölzli azündt
# Und das het e Flamme gäh
# Und i ha für d'Zigarette
# Welle Füür vom Hölzli näh
# Aber s'Hölzli isch dervo-
# Gspickt und uf e Deppich cho
# Und es hätt no fasch es Loch in Deppich gäh dervo

# %% [markdown]
# ---
# ### 1.3. Zeichnend programmieren lernen mit der Turtle
#
# Der `print()`-Befehl ist zwar äusserst nützlich, aber nun wollen wir unsere Programme grafisch sichtbar machen.
#
# Die Turtlegrafiken sind schon in den 1960-er Jahren mit der Programmiersprache Logo entstanden. Einer der Erfinder, Seymour Papert, war überzeugt, dass alle Kinder Programmieren lernen sollten. 1980 erschien sein Buch «Mindstorms» (nach dem später auch der Lego-Roboter benannt wurde). Darin beschrieb er, wie man Kindern das Programmieren näherbringen konnte. Kürzlich wurde es neu herausgegeben, aber die [Erstausgabe können Sie hier gratis lesen](https://mindstorms.media.mit.edu), wenn Sie neugierig sind.
#
# Auf dem Bild (Screenshot aus dem eBook) sehen Sie den Turtle-Roboter. Er liess sich mit der Sprache Logo programmieren. Die Logo-Turtle verfügte über einen Stift und kannte nur ganz wenige Befehle, mit denen man alles mögliche zeichnen konnte.
#
# <img src="./bilder/02_turtle.png" style="height:200px"/>
#
# Das Konzept hat sich bewährt und heute gibt es Turtlebibliotheken für verschiedenste Programmiersprachen.
#
# Dank dem Modul **ipyturtle3** können wir die Turtle direkt in Jupyter Notebooks nutzen.

# %% [markdown]
# **Damit die Verwendung von ipyturtle3 für Sie so angenehm wie möglich ist, müssen Sie die folgende Zelle in jedem Jupyter Notebook ausführen, bevor Sie Turtlegrafiken erstellen.**
#
# Danach können Sie Ihr Programm mit der folgenden Zeile beginnen:
#
# ```Python
# (t, tScreen) = prepareTurtleGraphics()
# ```
#
# <details>
#     <summary>
#          ► Wenn Sie mehr dazu wissen möchten, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
#
# `t` repräsentiert eine Turtle und `tScreen` das Zeichenfeld.
#
# Weitere Turtles können erstellt werden mit:
#
# ```Python
# blau = turtle.Turtle(tScreen)
# blau.color("blue")
# blau.shape("turtle")
# ```
#
# Optional kann auch die Grösse des Zeichenfelds festgelegt werden.
#
# Standardwerte: `width=500`, `height=250`
#
# ```Python
# (t,tScreen) = prepareTurtleGraphics(width, height)
# ```
# </details>

# %%
# Führen Sie diese Zelle aus, damit Sie weiter unten Turtlegrafiken machen können...

import ipyturtle3 as turtle

def prepareTurtleGraphics(width=500, height=250):
    myCanvas = turtle.Canvas(width=width, height=height)
    display(myCanvas)
    turtleScreen = turtle.TurtleScreen(myCanvas)
    turtleScreen.clear()
    t = turtle.Turtle(turtleScreen)
    t.shape("turtle")
    turtleScreen.bgcolor("floralwhite")
    return (t, turtleScreen)

# %% [markdown]
# ---
#
# **Aufgabe 2** – Turtle und Zeichenbereich erstellen
#
# Führen Sie die folgende Zelle aus.
#
# ```Python
# prepareTurtleGraphics()
# ```
# ist übrigens ein Befehl.
#
# Sehen Sie die Turtle?
#
# *Sie steht in der Mitte des (mit einer feinen Farbe markierten) Zeichenbereichs und schaut nach rechts.*

# %%
(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ---
# #### 1.3.1. Die Turtle steuern
#
# Die Turtle kennt ein paar **Befehle**.
#
# Mit den folgenden vier Basisbefehlen können Sie bereits vieles zeichnen:
#
# | Befehl   |      Abkürzung      |  Effekt |
# |:----------|:---------------|:-------|
# |forward(laenge) |  fd(laenge) | bewegt die Turtle um die angegebene Anzahl Pixel vorwärts.|
# |back(laenge) | bk(laenge) | bewegt die Turtle um die angegebene Anzahl Pixel rückwärts.|
# |right(winkel) | rt(winkel) | dreht die Turtle um den angegebenen Winkel (in Grad) nach rechts.|
# |left(winkel) | lt(winkel) | dreht die Turtle um den angegebenen Winkel (in Grad) nach links.|
#
#
# ---
# **Aufgabe 3** – Programm ausführen und beobachten
#
# * Versuchen Sie Schritt für Schritt zu verstehen, was dieses Programm macht.
# * Fügen Sie bei jeder Zeile einen Kommentar hinzu, der beschreibt, was geschieht.
# * Führen Sie es anschliessend aus, um Ihre Lösung zu überprüfen.
# * Was würde passieren, wenn die Befehle `t.forward(150)` und `t.left(45)` vertauscht würden?
# * Ändern Sie das Programm ab und überprüfen Sie, ob Sie Recht hatten.

# %%
# Lösung – Aufgabe 3:
# Originalprogramm:

(t, tScreen) = prepareTurtleGraphics() # Erstellt eine Turtle t und eine Zeichenfläche tScreen. 
                                       # (Die Turtle ist in der Mitte und ist nach rechts ausgerichtet.)

t.forward(150)                         # Lässt die Turtle t 150 Schritte vorwärts gehen.
t.left(45)                             # Dreht die Turtle um 45° nach links

# Beim Programm 
(t, tScreen) = prepareTurtleGraphics()
t.left(45)
t.forward(150)
# würde sich die Turtle erst 45° nach links drehen und dann 150 Schritte vorwärts gehen. 
# Die Linie wäre also nicht mehr horizontal
# Out:
# Canvas(height=250, width=500)
# Canvas(height=250, width=500)

# %% [markdown]
# ---
# Gerade hat sich wieder bestätigt: **Programme werden von oben nach unten ausgeführt!**
#
# #### 1.3.2. Die Turtle drehen
#
# Wie müssen Sie die Turtle drehen, um den gewünschten Winkel zu erreichen?
#
# Am einfachsten ist es, wenn Sie sich in die Turtle hineinversetzen. Manchmal hilft es auch, die Bewegungen mit einem Gegenstand, z.B. mit dem Deckel eines Stifts nachzuvollziehen.
#
# Wenn Sie beispielsweise ein gleichseitiges Dreieck zeichnen wollen, muss sich die Turtle bei jeder Ecke um den Aussenwinkel drehen:
#
# <img src="./bilder/02_turtle_innen-und_aussenwinkel.png" style="height:200px"/>
#
#
#
# ---
# **Aufgabe 4** – Zeichnen mit der Turtle
#
# Versuchen Sie nun mit Hilfe der vier Basisbefehle `forward()`, `back()`, `right()`, `left()` die folgenden Figuren zu zeichnen:
#
#     a) Ein Quadrat mit der Seitenlänge 100.
#
#     b) Ein gleichseitiges Dreieck mit der Seitenlänge 100 (Ausrichtung wie im Bild gezeigt; beginnen Sie bei der unteren Ecke).
#
#     c) Eine Treppe mit 3 Stufen (die Linien sollen je 30 Einheiten lang sein).
#
#     d) Ein Parallelogramm mit den Seitenlängen 90 und 60 und 45°-Winkeln.
#
# <details>
#     <summary>
#          ► Um zu sehen, wie Ihre Ausgabe aussehen soll, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
# a) <img src="./bilder/02_aufgabe-4a.png" width="50%">
# b) <img src="./bilder/02_aufgabe-4b.png" width="50%">
# c) <img src="./bilder/02_aufgabe-4c.png" width="50%">
# d) <img src="./bilder/02_aufgabe-4d.png" width="50%">
# </details>

# %%
# Lösung – Aufgabe 4.a)

(t, tScreen) = prepareTurtleGraphics()

t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 4.b)

(t, tScreen) = prepareTurtleGraphics()

t.left(30)
t.forward(100)
t.left(120)
t.forward(100)
t.left(120)
t.forward(100)
t.left(120)
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 4.c)

(t, tScreen) = prepareTurtleGraphics()

t.forward(30)
t.left(90)
t.forward(30)
t.right(90)
t.forward(30)
t.left(90)
t.forward(30)
t.right(90)
t.forward(30)
t.left(90)
t.forward(30)
t.right(90)
t.forward(30)
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 4.d)

(t, tScreen) = prepareTurtleGraphics()

t.forward(90)
t.left(45)
t.forward(60)
t.left(135)
t.forward(90)
t.left(45)
t.forward(60)
t.left(135)
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ---
# ## 2. Datentypen für Zahlen
#
# Vielleicht ist Ihnen aufgefallen, dass die Argumente der Turtle-Befehle `forward()`, `left()` etc. anders dargestellt werden als die bisher dem `print()`-Befehl übergebenen Argumente:
#
# ```Python
# print("Hallo!")
# t.forward(100)
# t.left(45)
# ```
#
# Dies liegt daran, dass Sie korrekterweise Zahlen und keinen Text übergeben haben.
#
# ***Spezialfall `print()`-Befehl***
#
# Der `print()`-Befehl ist etwas speziell. Er gibt alles aus, was er an Argumenten erhält.
#
# Er kann *beliebig viele* Argumente *aller möglichen Datentypen* entgegennehmen. Beim Turtle-Befehl `forward()` ist das anders.
#
# ### 2.1. TypeError: falscher Datentyp!
#
# Der Aufruf
#
# ```Python
# t.left("45")
# ```
#
# würde zu einer Fehlermeldung führen, weil Der Turtle-Befehl `left()` eine Zahl und keinen Text erwartet.
#
# In der Regel erwarten Funktionen für die Argumente vorher festgelegte Datentypen. Falls der Typ falsch ist, gibt es einen sogenannten *TypeError*.
#
# ---
# **Aufgabe 5** – TypeError
#
# Führen Sie das gegebene Programm aus.
#
# ```Python
# (t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen
# t.forward(100)
# ```
#
# Ändern Sie das Programm anschliessend so ab, dass Sie dem `forward()`-Befehl anstelle des Zahlenwerts einen String mit dem Wert 100 übergeben
#
# ```Python
# t.forward("100")
# ```
#
# und führen Sie das Programm aus. Sehen Sie den «TypeError»?

# %%
# Lösung – Aufgabe 5
(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

# t.forward(100) # korrekter Aufruf; führt zur gewünschten Ausgabe
# t.forward("100") # --> führt zu einem TypeError, da forward() eine Zahl erwartet, keinen Text.
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ---
# **Fehlermeldungen** sind *äusserst hilfreich* und den **TypeError** werden Sie häufig antreffen. Wenn Sie diese Fehlermeldung verstehen, können Sie den Fehler meist problemlos beheben!

# %% [markdown]
# ### 2.2. Datentyp erfragen
#
# Welchen Datentyp ein Wert hat, können Sie mit dem Befehl `type()` erfragen.
#
# ---
# **Aufgabe 6** – Datentypen erfragen
#
# Nutzen Sie den `type()`-Befehl um die Datentypen der folgenden Werte zu erfragen:
#
#     a) "Hallo"
#     b) 100
#     c) 100.0
#     d) -5.5
#
# Erstellen Sie für jede Teilaufgabe eine neue Codezelle.

# %%
# Lösung 6.a)
type("Hallo")
# Out:
# str

# %%
# Lösung 6.b)
type(100)
# Out:
# int

# %%
# Lösung 6.c)
type(100.0)
# Out:
# float

# %%
# Lösung 6.d)
type(-5.5)
# Out:
# float

# %% [markdown]
# ---
# ### 2.3. Datentypen Int und Float
#
# Bei der vorherigen Aufgabe haben Sie gesehen, dass die Werte `100` und `100.0` nicht dieselben Datentypen haben.
#
# In Python wird zwischen
# * **Ganzzahlen** (*Integer*, kurz: `int`; wir nennen Sie allgemein **«Integers»**) und
# * **Fliesskommazahlen** (*Floating Point Numbers*, kurz: `float`; wir nennen Sie allgemein **«Floats»**)
#
# unterschieden.

# %% [markdown]
# ### 2.4. Rechnen mit Zahlen – Arithmetische Operatoren
#
# Zum Rechnen mit Ganz- und Fliesskommazahlen stehen Ihnen in Python die folgenden arithmetischen Operatoren zur Verfügung:
#
# *Für die Beispiele gilt: `a = 2`, `b = 5`*
#
# | Operator | Operation                                                   | Beispiel     |
# |:--------:|:------------------------------------------------------------|:-------------|
# | +        | Addition                                                    | a + b —> 7   |
# | -        | Subtraktion                                                 | b - a —> 3   |
# | *        | Multiplikation                                              | a * b —> 10  |
# | /        | Division                                                    | a / b —> 0.4 |
# | //       | Ganzzahlige Division <br/>(abgerundet bzw. «abgeschnitten») | a // b —> 0  |
# | %        | Modulo (Rest der Division)                                  | a % b —> 2   |
# | **       | Potenz                                                      | a**b —> 32   |
#
# ---
# **Aufgabe 7** – Ein paar Rechnungen
#
# Sie haben vorher gesehen, dass die `print()`-Funktion sehr praktisch ist, denn Sie kann Argumente aller Datentypen verarbeiten. Deshalb verwenden wir hier die Print-Funktion, um die arithmetischen Operatoren auszuprobieren:
#
# Übergeben Sie der Print-Funktion die folgenden Rechnungen:
#
#     a) 10 + 4
#     b) 10 - 4
#     c) 10 * 4
#     d) 10 / 4
#     e) 10 // 4
#     f) 10 % 4
#     g) 10 ** 4
# es gilt übrigens die Klammerregel:
#
#     h) (74-29)/4
#
# Überprüfen Sie jeweils auch den Datentypen.
#
# Sie können dieses Beispiel als Vorlage verwenden:
# ```Python
# print(1.5 + 2.5)
# type(1.5 + 2.5)
# ```
# Erstellen Sie für jede Teilaufgabe eine neue Codezelle

# %%
print(1.5 + 2.5)
type(1.5 + 2.5)
# Out:
# 4.0
# float

# %%
# Lösung Aufgabe 7.a) Addition

print(10 + 4)
type(10 + 4)
# Out:
# 14
# int

# %%
# Lösung Aufgabe 7.b) Subtraktion

print(10 - 4)
type(10 - 4)
# Out:
# 6
# int

# %%
# Lösung Aufgabe 7.c) Multiplikation

print(10 * 4)
type(10 * 4)
# Out:
# 40
# int

# %%
# Lösung Aufgabe 7.d) Division

print(10 / 4)
type(10 / 4)
# Out:
# 2.5
# float

# %%
# Lösung Aufgabe 7.e) abgerundete (ganzzahlige) Division

print(10 // 4)
type(10 // 4)
# Out:
# 2
# int

# %%
# Lösung Aufgabe 7.f) Modulo (Rest)

print(10 % 4)
type(10 % 4)
# Out:
# 2
# int

# %%
# Lösung Aufgabe 7.g) Potenz

print(10 ** 4)
type(10 ** 4)
# Out:
# 10000
# int

# %%
# Lösung Aufgabe 7.h) Klammern

print((74-29)/4)
type((74-29)/4)
# Out:
# 11.25
# float

# %% [markdown]
# ---
# ## 3. Farbige Kunstwerke erstellen mit der Turtle
#
# Nun kommt Farbe ins Spiel! Die Turtle kann auch die Stiftfarbe und -Dicke verändern und die Figuren, die sie zeichnet, ausmalen. Damit wird es möglich, mit der Turtle farbige Kunstwerke zu erstellen.
#
# | Befehl   |      Abkürzung      |  Effekt |
# |:----------|:---------------|:-------|
# |color() | | Farbe der Turtle (und des Stifts), z.B. color("red") |
# |pencolor() | | Stiftfarbe (bei ausgefüllten Formen: Rand), z.B. pencolor("red") |
# |begin_fill()<br/>end_fill() | | Was zwischen `begin_fill()` und `end_fill()` gezeichnet wird,<br/>wird ausgefüllt. |
# |fillcolor() | | Füllfarbe|
# |pensize() | width() | Stiftbreite |
# |circle(r) | circle(r) | Kreis mit Radius r |
# |isdown() | | Gibt den Status des Stifts zurück: `true` für *down*, `false` für *up*. |
#
# Für die **Farben** können Sie gängige Farbnamen verwenden, z.B. "red", "green","blue", "orange", "purple", ... [Hier finden Sie 140 Farben mit ihren Codes.](https://trinket.io/docs/colors)<!--[Hier finden Sie eine Liste der möglichen Farbnamen](https://www.w3schools.com/colors/colors_names.asp)-->
#
# Auch die Hintergrundfarbe des Zeichenbereichs können Sie verändern. Den folgenden Befehl wenden Sie nicht auf die Turtle `t` an, sondern auf die Zeichenfläche `tScreen`:
#
# | Befehl    | Effekt |
# |:----------|:-------|
# | bgcolor() | Hintergrundfarbe definieren<br/>z.B. tScreen.bgcolor("lavender") |
#
# ### 3.1. Beispiel oranger, gelb ausgefüllter Kreis auf schwarzem Hintergrund
#
# ```python
# (t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen
#
# t.fillcolor("yellow")
# t.pencolor("orange")
#
# t.begin_fill()
# t.circle(50)
# t.end_fill()
#
# tScreen.bgcolor("black")
# ```
# Sie finden das Programm auch in der folgenden Zelle. Führen Sie es aus.

# %%
# Beispiel Kreis mit Radius 50, gelb ausgefüllt mit orangem Kreisbogen 

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.fillcolor("yellow")
t.pencolor("orange")

t.begin_fill()
t.circle(50)
t.end_fill()

# Hintergrund schwarz einfärben:
tScreen.bgcolor("black")
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# #### 1.3.3. Weitere Turtlebefehle
#
# Die Turtle kennt noch weitere Befehle.
#
# Sie kann beispielsweise den Stift hochheben und wieder absetzen und sie kann sich auch verstecken und wieder zeigen.
#
# | Befehl   |      Abkürzung      |  Effekt |
# |:----------|:---------------|:-------|
# |penup() | pu() | hebt den Stift von der Zeichenfläche hoch, damit die Turtle nicht mehr zeichnet. |
# |pendown() | pd() | setzt den Stift wieder auf die Zeichenfläche, damit die Turtle wieder zeichnet. |
# |hideturtle() | ht() | macht die Turtle unsichtbar.|
# |showturtle() | st() | macht die Turtle sichtbar. |
#
# ---
# **Aufgabe 8** – Gestrichelte Linie
#
# Zeichnen Sie eine 112 Schritte lange, grüne, gestrichelte Linie (die Striche haben eine Länge von 12, die Lücken eine Länge von 8. Die Turtle soll nach dem Zeichnen verschwinden.
#
# <details>
#     <summary>
#          ► Um zu sehen, wie Ihre Ausgabe aussehen soll, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
# <img src="./bilder/02_aufgabe-8.png" width="50%">
# </details>

# %%
# Lösung – Aufgabe 8

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.pencolor("green")
t.forward(12)
t.penup()
t.forward(8)
t.pendown()
t.forward(12)
t.penup()
t.forward(8)
t.pendown()
t.forward(12)
t.penup()
t.forward(8)
t.pendown()
t.forward(12)
t.penup()
t.forward(8)
t.pendown()
t.forward(12)
t.penup()
t.forward(8)
t.pendown()
t.forward(12)
t.hideturtle()
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ***
# **Aufgabe 9** – Ampel
#
# Ziel ist eine Ampel wie auf dem Bild.
# Die Ampel hat eine Breite von 30 (und eine Höhe von 80), die Lichter haben Radien von 10.
#
#     a) Zeichnen Sie einen vertikalen schwarzen Strich mit der Dicke 30 und der Länge 80.
#
#     b) Zeichnen Sie einen roten, ausgefüllten Kreis mit dem Radius 10
#
#     c) Fügen Sie die beiden Lösungen zusammen und zeichnen Sie die Ampel mit dem roten Licht.
#
#     d) Zeichnen Sie die ganze Ampel.
#
#
# <details>
#     <summary>
#          ► Um zu sehen, wie Ihre Ausgabe aussehen soll, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
# <img src="./bilder/02_aufgabe-9d.png" width="50%">
# </details>

# %%
# Lösung – Aufgabe 9.a):

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.left(90)
t.pensize(30)
t.forward(80)
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 9.b):

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.pencolor("red")
t.fillcolor("red")
t.begin_fill()
t.circle(10)
t.end_fill()
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 9.c):

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.left(90)
t.pensize(30)
t.forward(80)

t.pensize(1)
t.back(25)
t.right(90)
t.pencolor("red")
t.fillcolor("red")
t.begin_fill()
t.circle(10)
t.end_fill()
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Aufgabe 9.d):

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.left(90)
t.pensize(30)
t.forward(80)

t.pensize(1)
t.back(25)
t.right(90)
t.pencolor("red")
t.fillcolor("red")
t.begin_fill()
t.circle(10)
t.end_fill()

t.pencolor("black")
t.right(90)
t.forward(25)
t.left(90)

t.pencolor("orange")
t.fillcolor("orange")
t.begin_fill()
t.circle(10)
t.end_fill()

t.pencolor("black")
t.right(90)
t.forward(25)
t.left(90)

t.pencolor("green")
t.fillcolor("green")
t.begin_fill()
t.circle(10)
t.end_fill()

t.hideturtle()
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ### 3.2 Bonus: noch mehr Befehle
#
# Dieser Bereich ist optional und richtet sich an die bereits etwas Erfahreneren, die Schnellen und die Neugierigen.
#
# Manchmal sind auch noch andere Befehle hilfreich:
#
# Turtlebefehle zum «Aufräumen»:
#
# | Befehl   |      Abkürzung      |  Effekt |
# |:----------|:---------------|:-------|
# |home() | | bringt die Turtle wieder zur Mitte des Bildschirms und lässt sie wieder nach rechts blicken.<br/>Dabei ist der Stift in der gleichen Position (up oder down) wie vorher.|
# |clear() | | Löscht die Zeichnung; die Turtle bleibt an der Position, an der sie war. |
# |reset() | | Löscht die Zeichnung und bringt die Turtle in den Anfangszustand zurück<br/>(Mitte, Ausrichtung nach Rechts, schwarzer Stift, ...) |
#
#
# Turtlebefehle:
#
# | Befehl   |      Abkürzung      |  Effekt |
# |:----------|:---------------|:-------|
# |stamp() | | Die Turtle hinterlässt einen Abdruck. |
# |clone() | | Die Turtle wird dupliziert.<br/>(Es entsteht eine neue Turtle, die einen neuen Namen braucht...) |
#
# **Bonusaufgaben**
#
#     1) Zeichnen Sie eine Raute mit den Seitenlängen 100. In jeder Ecke soll ein Abdruck einer Turtle stehen bleiben.
#     a) Was würde passieren, wenn Sie am Ende des Programmes den Befehl t.reset() aufrufen würden?
#     b) Was würde passieren, wenn Sie am Ende des Programmes den Befehl t.clear() aufrufen würden?
#     c) Überlegen Sie sich auch, was bei diesen beiden Befehlen passieren würde, wenn die Turtle eine andere Farbe hätte.
#
#     2) Zeichnen Sie einen Pfeil nach oben: Die schwarze Turtle geht um 100 Einheiten nach oben. Oben wird sie geklont. Der linke Teil des Pfeils soll blau sein und von der einen Turtle gezeichnet werden, der rechte Teil des Pfeils soll rot sein und von der anderen Turtle gezeichnet werden.
#
# <details>
#     <summary>
#          ► Um zu sehen, wie Ihre Ausgabe aussehen soll, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
#
# 1) <img src="./bilder/02_aufgabe-bonus-1.png" width="50%">
# 2) <img src="./bilder/02_aufgabe-bonus-2.png" width="50%">
# </details>

# %%
# Lösung – Bonusaufgabe 1) Raute mit Schildkröten in den Ecken

(t, tScreen) = prepareTurtleGraphics()

t.left(30)
t.forward(100)
t.stamp()
t.left(120)
t.forward(100)
t.stamp()
t.left(60)
t.forward(100)
t.stamp()
t.left(120)
t.forward(100)
t.stamp()

# t.reset()
# Wenn Sie t.reset() aufrufen, wird die Zeichnung nach dem Zeichnen wieder gelöscht
# und die Turtle steht wieder in der Mitte und schaut nach rechts.
# Wenn die Turtle eine andere Farbe hätte, wäre sie nach dem Aufruf von t.reset() wieder schwarz.

# t.clear()
# Wenn Sie t.reset() aufrufen, wird die Zeichnung nach dem Zeichnen gelöscht
# aber die Turtle bleibt da stehen, wo sie ist.
# Wenn die Turtle eine andere Farbe hätte, würde sie die Farbe behalten.
# Out:
# Canvas(height=250, width=500)
# 10

# %%
# Lösung – Bonusaufgabe 2) Pfeil

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.lt(90)
t.fd(100)
t2=t.clone()
t.color("red")
t2.color("blue")
t.right(135)
t2.left(135)
t.forward(30)
t2.forward(30)
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ---
# # 4. Zusatzaufgaben
#
#     1) Zeichnen Sie einen Pfeil nach rechts mit einer gestrichelten Linie.
#        Die Striche haben eine Länge von 20, die Lücken eine Länge von 10, der Winkel des Pfeils beträgt 45°.
#        Die Turtle soll nach dem Zeichnen verschwinden.
#
#     2) Zeichnen Sie das Wappen des Kantons Zürich mit einer Seitenlänge von 100 und einem 3 Pixel breiten schwarzen Rahmen.
#        Tipp: Wenn Sie das Dreieck ausmalen, benötigen Sie nur zwei Seiten.
#
#     3) Was macht das folgende Programm:
# ```python
# (t, tScreen) = prepareTurtleGraphics()
# t.forward(100)
# t.pencolor("red")
# t.back(50)
# t.clear()
# ```
#
# <details>
#     <summary>
#          ► Um zu sehen, wie Ihre Ausgabe aussehen soll, klappen Sie diesen Bereich aus. ◀︎
#     </summary>
#
# 1) <img src="./bilder/02_aufgabe-zusatz-1.png" width="50%">
# 2) <img src="./bilder/02_aufgabe-zusatz-2.png" width="50%">
# </details>

# %%
# Lösung: Zusatzaufgabe 1) gestrichelter Pfeil

(t, tScreen) = prepareTurtleGraphics()

t.forward(20)
t.penup()
t.forward(10)
t.pendown()

t.forward(20)
t.penup()
t.forward(10)
t.pendown()

t.forward(20)
t.penup()
t.forward(10)
t.pendown()

t.left(135)
t.forward(20)
t.back(20)

t.left(90)
t.forward(20)

t.hideturtle()
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Zusatzaufgabe 2) Wappen des Kantons Zürich

(t, tScreen) = prepareTurtleGraphics()

t.color("white")
t.begin_fill()

t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.forward(100)
t.left(90)
t.end_fill()

t.color("blue")
t.penup()
t.forward(100)
t.left(180)
t.pendown()
t.begin_fill()
t.forward(100)
t.right(90)
t.forward(100)
t.end_fill()

t.color("black")
t.pensize(3)

t.right(90)
t.forward(101)
t.right(90)
t.forward(102)
t.right(90)
t.forward(102)
t.right(90)
t.forward(103)
t.right(90)
t.hideturtle()
# Out:
# Canvas(height=250, width=500)

# %%
# Lösung – Zusatzaufgabe 3) Führen Sie das Programm aus.

(t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen

t.forward(100) # Die Turtle geht 100 Schritte vorwärts.
t.pencolor("red") # Die Stiftfarbe wird auf rot gesetzt (erkennbar am Umriss der Turtle).
t.back(50) # Die Turtle geht 50 Schritte zurück.
#t.clear() # Die Zeichnung wird gelöscht, die Turtle bleibt, wo sie ist und wie sie ist. (Auskommentieren, um die Striche zu sehen...)
# Out:
# Canvas(height=250, width=500)

# %% [markdown]
# ## 4. Abschluss
#
# Sie haben nun gelernt, wie Programme ausgeführt werden und wie Sie Kommentare schreiben können, die nicht ausgeführt werden. Sie haben die Datentypen Integer und Float für Zahlen kennengelernt und die arithmetischen Operatoren, mit denen Sie mit den Zahlen rechnen können. Ausserdem haben Sie gesehen, wie Sie die Turtle steuern können, um mit ihr zu zeichnen.
#
# ### ✅ Kontrollfragen
#
# Zum Überprüfen finden Sie hier ein paar Kontrollfragen:
#
# 1. Wie wird das folgende Programm ausgeführt? Notieren Sie die Zeilennummern.
#
# ```Python
# 1. print("Hallo!")
# 2. (t, tScreen) = prepareTurtleGraphics() # eine Turtle t und einen Zeichenbereich tScreen erstellen
# 3. t.forward(100)
# 4. t.left(120)
# 5. # t.back(20)
# 6. t.pencolor("green")
# 7. t.circle(50)
# ```
#
# 2. Wie ist ein Befehl aufgebaut?
#
# 3. Wie würden Sie die folgende Zeichnung programmieren?
#    <img src="./bilder/02_kontrollfrage-3.png">
#
# 4. Welche Ausgabe erwarten Sie für
#
#    ```python
#    a) print(22 // 5)
#    b) print(2 ** 3)
#    c) print((5*7) % 3)
#    ```
#
# 5. Welchen Operator benötigen Sie für die
#    a) Multiplikation?
#    b) Division
#
# 6. Was bedeutet Modulo und welchen Operator benötigen Sie für eine Modulo-Operation?
#
# 7. Wozu dient der Befehl `type()`?
#
# 8. Welche Ausgabe erwarten Sie für die folgenden Aufrufe des `type()`-Befehls?
#    ```python
#    a) type(22 // 5)
#    b) type(22 / 5)
#    c) type("22 / 5")
#    d) type(2 ** 3)
#    ```

# %% [markdown]
# ### ✍️ Prüfungsvorbereitung
#
# 1. Schreiben Sie ein Programm, das einen 3 Pixel dicken grauen Rahmen um das Zeichenfeld zeichnet.
# 2. Ändern Sie das Programm von 1. so ab, dass nur die Ecken (je 20 Pixel weit) markiert werden.
# 3. Zeichnen Sie die folgende Figur (die Zacken sind je 30 hoch und 30 breit):
# <img src="./bilder/02_pruefungsvorbereitung-3.png" width="50%">
# 4. Im folgenden Programm haben sich 5 Fehler eingeschlichen. Markieren Sie die Zeilennummern und testen Sie, ob Ihr Programm läuft.
#
# ```Python
# 01. t.pencolor(red)
# 02. t.forward(50)
# 03. t.penup()
# 04. t.forward(50)
# 05. t.pendown()
# 06. t.left(90)
# 07. t.pen_size(5)
# 08. t.forward(100)
# 09. t.left("90")
# 10. t.forward("100")
# 11. hideturtle()
# ```
